# %%
import numpy as np
import pandas as pd

import extract

# %% [markdown]
# ## Resources from the [football-data.org](https://www.football-data.org/documentation/quickstart) API
#
# - competitions
# - matches
# - players
# - scorers
# - teams

# %%
def get_key_from_dictionary(obj, key):
    if not isinstance(obj, dict):
        return obj
    return obj.get(key)


def get_scoreline(data):
    score_pens = data['penalties']
    score_ft = data['fullTime']
    home_goals = score_ft['homeTeam']
    away_goals = score_ft['awayTeam']
    if type(score_pens['homeTeam']) is int:
        home_pens = score_pens['homeTeam']
        away_pens = score_pens['awayTeam']
        return f"{home_goals}-{away_goals} ({home_pens}-{away_pens} pens)"
    return f"{home_goals}-{away_goals}"


def get_goals_scored_from_scoreline(scoreline, by):
    if type(scoreline) is str:
        scoreline = scoreline.replace(' ', '')[:3]
        if '-' not in scoreline:
            return None
        home_goals, away_goals = scoreline.split('-')
        if by == 'home':
            return home_goals
        elif by == 'away':
            return away_goals
    return None


def clean_scorelines(data):
    data['homeGoals'] = data['score'].apply(get_goals_scored_from_scoreline, by='home')
    data['awayGoals'] = data['score'].apply(get_goals_scored_from_scoreline, by='away')
    return data


def get_refereeing_team(data):
    referee_team = ""
    for data_obj in data:
        if data_obj['name']:            
            referee_team += str(data_obj['name'])
            referee_team += ', '
    num_chars = len(referee_team)
    return referee_team[:num_chars-2]


# def convert_to_integer(obj):
#     try:
#         obj = int(obj)
#     except ValueError:
#         pass
#     return obj

# %% [markdown]
# ## competitions and matches

# %%
# %%time
dictionary_response = extract.get_raw_data(api_endpoint="/v2/competitions/CL/matches")
print(dictionary_response.keys())
# Out:
# dict_keys(['count', 'filters', 'competition', 'matches'])
# Wall time: 2.3 s

# %%
df = pd.DataFrame(data=dictionary_response['matches'])
df['competition'] = dictionary_response['competition']['name']

# %%
print(df.shape)
df.sample(3)
# Out:
# (205, 14)
#          id                                             season  \
# 180  283583  {'id': 495, 'startDate': '2019-06-25', 'endDat...
# 109  283551  {'id': 495, 'startDate': '2019-06-25', 'endDat...
# 188  285538  {'id': 495, 'startDate': '2019-06-25', 'endDat...
#
#                   utcDate    status  matchday        stage    group  \
# 180  2019-12-11T17:55:00Z  FINISHED       6.0  GROUP_STAGE  Group C
# 109  2019-10-01T19:00:00Z  FINISHED       2.0  GROUP_STAGE  Group A
# 188  2020-02-18T20:00:00Z  FINISHED       NaN  ROUND_OF_16     None
#
#               lastUpdated                                               odds  \
# 180  2019-12-12T20:20:00Z  {'msg': 'Activate Odds-Package in User-Panel t...
# 109  2019-10-02T04:20:01Z  {'msg': 'Activate Odds-Package in User-Panel t...
# 188  2020-02-19T20:50:00Z  {'msg': 'Activate Odds-Package in User-Panel t...
#
#                                                  score  \
# 180  {'winner': 'AWAY_TEAM', 'duration': 'REGULAR',...
# 109  {'winner': 'AWAY_TEAM', 'duration': 'REGULAR',...
# 188  {'winner': 'HOME_TEAM', 'duration': 'REGULAR',...
#
#                                           homeTeam  \
# 180       {'id': 755, 'name': 'GNK Dinamo Zagreb'}
# 109          {'id': 610, 'name': 'Galatasaray SK'}
# 188  {'id': 78, 'name': 'Club Atlético de Madrid'}
#
#                                           awayTeam  \
# 180       {'id': 65, 'name': 'Manchester City FC'}
# 109  {'id': 524, 'name': 'Paris Saint-Germain FC'}
# 188             {'id': 64, 'name': 'Liverpool FC'}
#
#                                               referees            competition
# 180  [{'id': 43843, 'name': 'Carlos del Cerro', 'na...  UEFA Champions League
# 109  [{'id': 43888, 'name': 'Szymon Marciniak', 'na...  UEFA Champions League
# 188  [{'id': 43888, 'name': 'Szymon Marciniak', 'na...  UEFA Champions League

# %%
resource_competitions_cols = df.columns.tolist()

# %%
columns_to_get_name = ['competition', 'homeTeam', 'awayTeam']
columns_in_dataframe = df.columns.tolist()
for column in columns_to_get_name:
    if column in columns_in_dataframe:
        df[column] = df[column].apply(get_key_from_dictionary, key='name')

df['score'] = df['score'].apply(get_scoreline)
df = clean_scorelines(data=df)

df['referees'] = df['referees'].apply(get_refereeing_team)
df['utcDate'] = pd.to_datetime(arg=df['utcDate'])
df.drop(labels=['lastUpdated', 'season', 'odds'], axis=1, inplace=True)

column_order = [
    'id', 'utcDate', 'competition', 'matchday', 'homeTeam', 'homeGoals', 'awayGoals', 'awayTeam',
    'score', 'group', 'stage', 'referees', 'status'
]

columns_in_dataframe = df.columns.tolist()
for column in column_order:
    if column not in columns_in_dataframe:
        column_order.remove(column)

df = df.loc[:, column_order]

# %%
# df[(df['stage'] == 'ROUND_OF_16') & (df['status'] == 'FINISHED')].sample(5)

# team = 'Real Madrid CF'
# df[(df['homeTeam'] == team) | (df['awayTeam'] == team)].sample(3)

# %%
print(df.shape)
df.sample(3)
# Out:
# (205, 13)
#          id                   utcDate            competition  matchday  \
# 44   278366 2019-07-24 18:45:00+00:00  UEFA Champions League       NaN
# 4    269481 2019-07-09 14:00:00+00:00  UEFA Champions League       NaN
# 121  283634 2019-10-02 19:00:00+00:00  UEFA Champions League       2.0
#
#               homeTeam homeGoals awayGoals          awayTeam score    group  \
# 44          Dundalk FC         1         1  Qarabağ Ağdam FK   1-1     None
# 4    FC Ararat-Armenia         2         1       AIK Fotboll   2-1     None
# 121          Lille OSC         1         2        Chelsea FC   1-2  Group H
#
#                     stage                                           referees  \
# 44   2ND_QUALIFYING_ROUND  Bartosz Frankowski, Marcin Boniek, Jakub Winkl...
# 4    1ST_QUALIFYING_ROUND  Duje Strukan, Hrvoje Radić, Mario Pepur, Marin...
# 121           GROUP_STAGE  Aliaksei Kulbakov, Dmitry Zhuk, Oleg Maslyanko...
#
#        status
# 44   FINISHED
# 4    FINISHED
# 121  FINISHED

# %%
df[df['score'].str.contains('pens')]
# Out:
#         id                   utcDate            competition  matchday  \
# 25  269502 2019-07-17 16:30:00+00:00  UEFA Champions League       NaN
# 32  269496 2019-07-17 18:15:00+00:00  UEFA Champions League       NaN
# 72  279612 2019-08-13 18:00:00+00:00  UEFA Champions League       NaN
#
#               homeTeam homeGoals awayGoals              awayTeam  \
# 25             Rīga FC         0         0            Dundalk FC
# 32  FK Sutjeska Nikšić         1         1  ŠK Slovan Bratislava
# 72        FC København         1         1      FK Crvena Zvezda
#
#              score group                 stage  \
# 25  0-0 (4-5 pens)  None  1ST_QUALIFYING_ROUND
# 32  1-1 (3-2 pens)  None  1ST_QUALIFYING_ROUND
# 72  1-1 (6-7 pens)  None  3RD_QUALIFYING_ROUND
#
#                                              referees    status
# 25                 Dimitar Mečkarovski, Goce Petreski  FINISHED
# 32  Horațiu Fesnic, Alexandru Cerei, Mihai Marica,...  FINISHED
# 72  Gediminas Mažeika, Vytautas Šimkus, Vytenis Ka...  FINISHED

# %% [markdown]
# ## players

# %%
# %%time
dictionary_response = extract.get_raw_data(api_endpoint="/v2/players/320/matches") # ?status=FINISHED
print(dictionary_response.keys())
# Out:
# dict_keys(['count', 'filters', 'player', 'matches'])
# Wall time: 1.9 s

# %%
df = pd.DataFrame(data=dictionary_response['matches'])
df['player'] = dictionary_response['player']['name']
df.shape
# Out:
# (88, 15)

# %%
df.sample(3)
# Out:
#         id                         competition  \
# 23  271508  {'id': 2002, 'name': 'Bundesliga'}
# 78  201066  {'id': 2002, 'name': 'Bundesliga'}
# 40  235962  {'id': 2002, 'name': 'Bundesliga'}
#
#                                                season               utcDate  \
# 23  {'id': 474, 'startDate': '2019-08-16', 'endDat...  2019-11-10T14:30:00Z
# 78  {'id': 3, 'startDate': '2017-08-18', 'endDate'...  2017-11-05T14:30:00Z
# 40  {'id': 155, 'startDate': '2018-08-24', 'endDat...  2019-04-28T13:30:00Z
#
#       status  matchday           stage           group           lastUpdated  \
# 23  FINISHED      11.0  REGULAR_SEASON  Regular Season  2019-11-11T14:50:05Z
# 78  FINISHED      11.0  REGULAR_SEASON  Regular Season  2018-06-22T09:02:54Z
# 40  FINISHED      31.0  REGULAR_SEASON  Regular Season  2019-04-28T18:30:26Z
#
#                                                  odds  \
# 23  {'msg': 'Activate Odds-Package in User-Panel t...
# 78  {'msg': 'Activate Odds-Package in User-Panel t...
# 40  {'msg': 'Activate Odds-Package in User-Panel t...
#
#                                                 score  \
# 23  {'winner': 'AWAY_TEAM', 'duration': 'REGULAR',...
# 78  {'winner': 'AWAY_TEAM', 'duration': 'REGULAR',...
# 40  {'winner': 'AWAY_TEAM', 'duration': 'REGULAR',...
#
#                                     homeTeam  \
# 23       {'id': 11, 'name': 'VfL Wolfsburg'}
# 78           {'id': 1, 'name': '1. FC Köln'}
# 40  {'id': 2, 'name': 'TSG 1899 Hoffenheim'}
#
#                                     awayTeam  \
# 23  {'id': 3, 'name': 'Bayer 04 Leverkusen'}
# 78  {'id': 2, 'name': 'TSG 1899 Hoffenheim'}
# 40       {'id': 11, 'name': 'VfL Wolfsburg'}
#
#                                              referees        player
# 23  [{'id': 57510, 'name': 'Manuel Gräfe', 'nation...  Nadiem Amiri
# 78  [{'id': 8825, 'name': 'Deniz Aytekin', 'nation...  Nadiem Amiri
# 40  [{'id': 8825, 'name': 'Deniz Aytekin', 'nation...  Nadiem Amiri

# %%
resource_players_cols = df.columns.tolist()

# %%
print(set(resource_competitions_cols).difference(set(resource_players_cols)))

print(set(resource_players_cols).difference(set(resource_competitions_cols)))
# Out:
# set()
# {'player'}

# %%
columns_to_get_name = ['competition', 'homeTeam', 'awayTeam']
columns_in_dataframe = df.columns.tolist()
for column in columns_to_get_name:
    if column in columns_in_dataframe:
        df[column] = df[column].apply(get_key_from_dictionary, key='name')

df['score'] = df['score'].apply(get_scoreline)
df = clean_scorelines(data=df)

df['referees'] = df['referees'].apply(get_refereeing_team)
df['utcDate'] = pd.to_datetime(arg=df['utcDate'])
df.drop(labels=['lastUpdated', 'season', 'odds'], axis=1, inplace=True)

column_order = [
    'id', 'player', 'utcDate', 'competition', 'matchday', 'homeTeam', 'homeGoals', 'awayGoals', 'awayTeam',
    'score', 'group', 'stage', 'referees', 'status'
]

columns_in_dataframe = df.columns.tolist()
for column in column_order:
    if column not in columns_in_dataframe:
        column_order.remove(column)

df = df.loc[:, column_order]

# %%
print(df.shape)
df.sample(3)
# Out:
# (88, 14)
#         id        player                   utcDate competition  matchday  \
# 25  271497  Nadiem Amiri 2019-11-02 14:30:00+00:00  Bundesliga      10.0
# 74  201102  Nadiem Amiri 2017-12-10 14:30:00+00:00  Bundesliga      15.0
# 52  235854  Nadiem Amiri 2019-01-26 14:30:00+00:00  Bundesliga      19.0
#
#                homeTeam homeGoals awayGoals                  awayTeam score  \
# 25  Bayer 04 Leverkusen         1         2  Borussia Mönchengladbach   1-2
# 74          Hannover 96         2         0       TSG 1899 Hoffenheim   2-0
# 52          SC Freiburg         2         4       TSG 1899 Hoffenheim   2-4
#
#              group           stage  \
# 25  Regular Season  REGULAR_SEASON
# 74  Regular Season  REGULAR_SEASON
# 52  Regular Season  REGULAR_SEASON
#
#                                              referees    status
# 25  Daniel Siebert, Lasse Koslowski, Jan Seidel, C...  FINISHED
# 74  Markus Schmidt, Thorben Siewer, Daniel Schlage...  FINISHED
# 52  Bibiana Steinhaus, Guido Kleve, Thomas Stein, ...  FINISHED

# %% [markdown]
# ## teams

# %%
# %%time
dictionary_response = extract.get_raw_data(api_endpoint="/v2/teams/5")
print(dictionary_response.keys())
# Out:
# dict_keys(['id', 'area', 'activeCompetitions', 'name', 'shortName', 'tla', 'crestUrl', 'address', 'phone', 'website', 'email', 'founded', 'clubColors', 'venue', 'squad', 'lastUpdated'])
# Wall time: 761 ms

# %%
df_by_team = pd.DataFrame(data=dictionary_response['squad'])

# %%
df_by_team.sample(3)
# Out:
#       id            name    position           dateOfBirth countryOfBirth  \
# 28  6543  Jann-Fiete Arp    Attacker  2000-01-06T00:00:00Z        Germany
# 1    342    Sven Ulreich  Goalkeeper  1988-08-03T00:00:00Z        Germany
# 27  3184      Leroy Sané    Attacker  1996-01-11T00:00:00Z        Germany
#
#    nationality  shirtNumber    role
# 28     Germany          NaN  PLAYER
# 1      Germany          NaN  PLAYER
# 27     Germany         19.0  PLAYER

# %% [markdown]
# ## scorers

# %%
# %%time
dictionary_response = extract.get_raw_data(api_endpoint="/v2/competitions/CL/scorers?limit=40")
print(dictionary_response.keys())
# Out:
# dict_keys(['count', 'filters', 'competition', 'season', 'scorers'])
# Wall time: 1.55 s

# %%
df_top_scorers = pd.DataFrame(data=dictionary_response['scorers'])

# %%
df_top_scorers.head(3)
# Out:
#                                               player  \
# 0  {'id': 371, 'name': 'Robert Lewandowski', 'fir...
# 1  {'id': 38101, 'name': 'Erling Haaland', 'first...
# 2  {'id': 73401, 'name': 'Mislav Oršić', 'firstNa...
#
#                                            team  numberOfGoals
# 0        {'id': 5, 'name': 'FC Bayern München'}             11
# 1  {'id': 4, 'name': 'BV Borussia 09 Dortmund'}             10
# 2      {'id': 755, 'name': 'GNK Dinamo Zagreb'}              7

# %%
df_top_scorers['playerId'] = df_top_scorers['player'].apply(get_key_from_dictionary, key='id')
df_top_scorers['playerName'] = df_top_scorers['player'].apply(get_key_from_dictionary, key='name')
df_top_scorers['playerDob'] = df_top_scorers['player'].apply(get_key_from_dictionary, key='dateOfBirth')
df_top_scorers['playerNationality'] = df_top_scorers['player'].apply(get_key_from_dictionary, key='nationality')
df_top_scorers['playerPosition'] = df_top_scorers['player'].apply(get_key_from_dictionary, key='position')

df_top_scorers['teamId'] = df_top_scorers['team'].apply(get_key_from_dictionary, key='id')
df_top_scorers['teamName'] = df_top_scorers['team'].apply(get_key_from_dictionary, key='name')

df_top_scorers['playerDob'] = pd.to_datetime(arg=df_top_scorers['playerDob'])
df_top_scorers.drop(labels=['player', 'team'], axis=1, inplace=True)

# %%
df_top_scorers.head(3)
# Out:
#    numberOfGoals  playerId          playerName  playerDob playerNationality  \
# 0             11       371  Robert Lewandowski 1988-08-21            Poland
# 1             10     38101      Erling Haaland 2000-07-21            Norway
# 2              7     73401        Mislav Oršić 1992-12-29           Croatia
#
#   playerPosition  teamId                 teamName
# 0       Attacker       5        FC Bayern München
# 1       Attacker       4  BV Borussia 09 Dortmund
# 2       Attacker     755        GNK Dinamo Zagreb

# %%
df_top_scorers.dtypes
# Out:
# numberOfGoals                 int64
# playerId                      int64
# playerName                   object
# playerDob            datetime64[ns]
# playerNationality            object
# playerPosition               object
# teamId                        int64
# teamName                     object
# dtype: object

# %%
df_top_scorers
# Out:
#     numberOfGoals  playerId              playerName  playerDob  \
# 0              11       371      Robert Lewandowski 1988-08-21
# 1              10     38101          Erling Haaland 2000-07-21
# 2               7     73401            Mislav Oršić 1992-12-29
# 3               6     36746           Billel Omrani 1993-06-02
# 4               6      2103           Dries Mertens 1987-05-06
# 5               6      8004              Harry Kane 1993-07-28
# 6               6       311            Serge Gnabry 1995-07-14
# 7               5     16207     Alexander Søderlund 1987-08-03
# 8               5     15549        Anders Konradsen 1990-07-18
# 9               5      2174          Bruno Petković 1994-09-16
# 10              5     23132               Dani Olmo 1998-05-07
# 11              5    122469        Youssef El Arabi 1987-02-03
# 12              5      8472           Memphis Depay 1994-02-13
# 13              5      3236           Gabriel Jesus 1997-04-03
# 14              5      2014            Mauro Icardi 1993-02-19
# 15              5      3343            Son Heungmin 1992-07-08
# 16              5      3329         Raheem Sterling 1994-12-08
# 17              5      3220        Lautaro Martínez 1997-08-22
# 18              5      3374           Kylian Mbappé 1998-12-20
# 19              5      1845            Josip Iličić 1988-01-29
# 20              4     34495           Ryan Christie 1995-04-28
# 21              4     33110            Rúben Semedo 1994-04-04
# 22              4      8888            Hans Vanaken 1992-08-24
# 23              4      3187             Timo Werner 1996-03-06
# 24              4     16148           Quincy Promes 1992-01-04
# 25              4        53           Achraf Hakimi 1998-11-04
# 26              4      3754           Mohamed Salah 1992-06-15
# 27              4      9551         Marcel Sabitzer 1994-03-17
# 28              4      1324                 Rodrygo 2001-01-09
# 29              4        49           Karim Benzema 1987-12-19
# 30              4      3494           Emil Forsberg 1991-10-23
# 31              3     38485            Tokmac Nguen 1993-10-20
# 32              3     67822          Rok Kronaveter 1986-12-07
# 33              3     56442              Riku Riski 1989-08-16
# 34              3     31153            Henok Goitom 1984-09-16
# 35              3     21845  Richmond Boakye Yiadom 1993-01-28
# 36              3     15518        Andrija Pavlović 1993-11-16
# 37              3      3707            Hakim Ziyech 1993-03-19
# 38              3      3444             Dušan Tadić 1988-11-20
# 39              3      8894         Emmanuel Dennis 1997-11-15
#
#    playerNationality playerPosition  teamId                  teamName
# 0             Poland       Attacker       5         FC Bayern München
# 1             Norway       Attacker       4   BV Borussia 09 Dortmund
# 2            Croatia       Attacker     755         GNK Dinamo Zagreb
# 3             France       Attacker    5515          FC CFR 1907 Cluj
# 4            Belgium       Attacker     113                SSC Napoli
# 5            England       Attacker      73      Tottenham Hotspur FC
# 6            Germany     Midfielder       5         FC Bayern München
# 7             Norway       Attacker     889              Rosenborg BK
# 8             Norway     Midfielder     889              Rosenborg BK
# 9            Croatia       Attacker     755         GNK Dinamo Zagreb
# 10             Spain     Midfielder     755         GNK Dinamo Zagreb
# 11           Morocco       Attacker     654        PAE Olympiakos SFP
# 12       Netherlands       Attacker     523        Olympique Lyonnais
# 13            Brazil       Attacker      65        Manchester City FC
# 14         Argentina       Attacker     524    Paris Saint-Germain FC
# 15    Korea Republic       Attacker      73      Tottenham Hotspur FC
# 16           England       Attacker      65        Manchester City FC
# 17         Argentina       Attacker     108  FC Internazionale Milano
# 18            France       Attacker     524    Paris Saint-Germain FC
# 19          Slovenia     Midfielder     102               Atalanta BC
# 20          Scotland     Midfielder     732                 Celtic FC
# 21          Portugal       Defender     654        PAE Olympiakos SFP
# 22           Belgium     Midfielder     851            Club Brugge KV
# 23           Germany       Attacker     721                RB Leipzig
# 24       Netherlands       Attacker     678                  AFC Ajax
# 25           Morocco       Defender       4   BV Borussia 09 Dortmund
# 26             Egypt       Attacker      64              Liverpool FC
# 27           Austria       Attacker     721                RB Leipzig
# 28            Brazil       Attacker      86            Real Madrid CF
# 29            France       Attacker      86            Real Madrid CF
# 30            Sweden     Midfielder     721                RB Leipzig
# 31       South Sudan     Midfielder    5954           Ferencvárosi TC
# 32          Slovenia     Midfielder     734                NK Maribor
# 33           Finland       Attacker    5123              Helsingin JK
# 34           Eritrea       Attacker    5277               AIK Fotboll
# 35             Ghana       Attacker    7283          FK Crvena Zvezda
# 36            Serbia       Attacker     752                  APOEL FC
# 37           Morocco     Midfielder     678                  AFC Ajax
# 38            Serbia       Attacker     678                  AFC Ajax
# 39           Nigeria       Attacker     851            Club Brugge KV

# %% [markdown]
# # Testing
